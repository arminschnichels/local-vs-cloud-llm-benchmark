# %%
import pandas as pd
import numpy as np

# %%
file_path = "../data/restaurant_reviews_sample.csv"

df = pd.read_csv(file_path)

# %%
df.info()

# %%
df["ground_truths_overall"] = np.nan
df["ground_truths_food"] = np.nan
df["ground_truths_service"] = np.nan
df["ground_truths_price"] = np.nan
df["ground_truths_ambiance"] = np.nan

# Check the dataframe to see the new empty columns
df.head(2)

# %%
df.to_csv("../data/reviews_to_label.csv", index=False)
